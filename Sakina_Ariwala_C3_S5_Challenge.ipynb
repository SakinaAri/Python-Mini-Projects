# %% [markdown]
# # Sakina_Ariwala_C3_S5_Challenge

# %% [markdown]
# # TASK :- Make a conversion app

# %%
import math
import statistics

def getInput():
    x = (input("Enter the value of x : "))
    y = (input("Enter the value of y : "))
    return x , y 
    
    
    
def radians_to_degree(x):
    print("The value of ",x," in degrees will be",math.degrees(x),"°")

def degree_to_radians(x):
    print("The value of ",x,"° in radians will be",math.radians(x))

def Number_to_Factorial(x):
    print("The value of factorial of  ",x," will be",math.factorial(x))           

def Number_to_sqaureroot(x):            
    print("The value of sqaureroot of  ",x," will be",math.sqrt(x))

def Megabite_to_Nibble(x):
     #1 megabite = 2000000 nibble
    print("The value of ",x," in nibbles will be",x*2000000)

def Fraction_to_Decimal(x,y):
    decimal = x/y
    print("The decimal value of",x/y,"is ",decimal)

def kmph_to_mps(x):
    print("speed_in_mps = ", 0.277778 * x,"M/sec")

def mps_to_kmph(x):
    print(" speed_in_kmph = ", 3.6 * x)

def Integer_to_Float(x):
    print("The value of ",x," when converted to float will be ",math.floor(x))

def Float_to_Integer(x):
    print("The value of ",x," when converted to int  will be ",int(x))

def Decimal_to_octal(x):
    print("The value of ",x," when converted to octal value  will be ",oct(x))

def octal_to_Decimal(x):
    print("The value of ",x," when converted to octal value  will be ",int(x,8))

def Decimal_to_hexadecimal(x):
    print("The value of ",x," when converted to hexadecimal  will be ",hex(x))

def Hexadecimal_to_decimal(x):
    print("The value of ",x," when converted to decimal will be ",int(x, 16))        

def Decimal_to_binary(x):
    print("The value of ",x," when converted to binary  will be ",bin(x).replace("0b", ""))

def Binary_to_decimal(x):  
    print("The value of ",x," when converted to binary will be ",int(x,2))

def Character_to_ASCII(x):
    print("The value of CHAR ",x," in ASCII will be",ascii(x))

def ASCII_to_Character(x):
    print("The value of ASCII Code ",x," as char will be",chr(x))

def Celsius_to_fahrenhite(x):
    fahrenheit = (x * 1.8) + 32
    print("The value of ",x,"°Celsius in fahrenheit will be",fahrenheit)

def fahrenhite_to_Celsius(x):
    Celsius = (5/9) * (x - 32)
    print("The value of ",x," in celsius will be",Celsius,"°Celsius")



def main():
    
            print("----------MENU------------")
            print("1 : Radiance to Degree")
            print("2 : Degree to Radiance")
            print("3 : Number to its Factorial")
            print("4 : Number to its sqaure root")
            print("5 : Megabite to Nibble")
            print("6 : Fraction to Decimal")
            print("7 : Km/Hr to M/sec")
            print("8 : M/sec  to Km/Hr")
            print("9 : Integer to Float")
            print("10: Float to integer")
            print("11: Decimal to octal")
            print("12: octal to Decimal")
            print("13: Decimal to Hexadecimal")
            print("14: Hexadecimal to decimal")
            print("15: Decimal to Binary")
            print("16: Binary to decimal")
            print("17:Character to ASCII")
            print("18:ASCII  to Character")
            print("19:Celsius to fahrenhite")
            print("20:fahrenhite to Celsius")
            print("21: Exit!")

main()
while True:
            
            print()
            choice = int(input("Enter your choice : "))
            print()
            if choice==1:
                x = getInput()
                radians_to_degree(int(x[0]))
            elif choice==2:
                x = getInput()
                degree_to_radians(int(x[0]))
            elif choice==3:
                x = getInput()
                Number_to_Factorial(int(x[0]))
            elif choice==4:
                x = getInput()
                Number_to_sqaureroot(int(x[0]))
            elif choice==5:
                x = getInput()
                Megabite_to_Nibble(int(x[0]))
            elif choice==6:
                x = getInput()
                Fraction_to_Decimal(int(x[0]),int(x[1]))
            elif choice==7:
                x = getInput()
                kmph_to_mps(int(x[0]))
            elif choice==8:
                x = getInput()
                mps_to_kmph(int(x[0]))
            elif choice==9:
                x = getInput()
                Integer_to_Float(int(x[0]))
            elif choice==10:
                x = getInput()
                Float_to_Integer(float(x[0]))
            elif choice==11:
                x = getInput()
                Decimal_to_octal(int(x[0]))
            elif choice==12:
                x = getInput()
                octal_to_Decimal((x[0]))
            elif choice==13:
                x = getInput()
                Decimal_to_hexadecimal(int(x[0]))
            elif choice==14:
                x = getInput()
                Hexadecimal_to_decimal((x[0]))
            elif choice==15:
                x = getInput()
                Decimal_to_binary(int(x[0]))
            elif choice==16:
                x = getInput()
                Binary_to_decimal((x[0]))
            elif choice==17:
                x = getInput()
                Character_to_ASCII((x[0]))
            elif choice==18:
                x = getInput()
                ASCII_to_Character(int(x[0]))
            elif choice==19:
                x = getInput()
                Celsius_to_fahrenhite(int(x[0]))
            elif choice==20:
                x = getInput()
                fahrenhite_to_Celsius(int(x[0]))
            elif choice==21:
                print("Thank you!")
                
                break
            else:
                print("Invalid! Please enter a valid choice")
# Out:
# ----------MENU------------
# 1 : Radiance to Degree
# 2 : Degree to Radiance
# 3 : Number to its Factorial
# 4 : Number to its sqaure root
# 5 : Megabite to Nibble
# 6 : Fraction to Decimal
# 7 : Km/Hr to M/sec
# 8 : M/sec  to Km/Hr
# 9 : Integer to Float
# 10: Float to integer
# 11: Decimal to octal
# 12: octal to Decimal
# 13: Decimal to Hexadecimal
# 14: Hexadecimal to decimal
# 15: Decimal to Binary
# 16: Binary to decimal
# 17:Character to ASCII
# 18:ASCII  to Character
# 19:Celsius to fahrenhite
# 20:fahrenhite to Celsius
# 21: Exit!
#
# Enter your choice : 16
#
# Enter the value of x : 10
# Enter the value of y : 7
# The value of  10  when converted to binary will be  2
#
# Enter your choice : 21
#
# Thank you!
